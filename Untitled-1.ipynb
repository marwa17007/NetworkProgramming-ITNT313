# %%
pip install LDAP
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   DEPRECATION: LDAP is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for LDAP ... error
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for LDAP did not run successfully.
#   │ exit code: 1
#   ╰─> [100 lines of output]
#       running install
#       /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running build_py
# ...

# %%
import python-ldap

# Define the LDAP connection parameters
host = "ldap://192.168.1.1"
port = 389
user = "CN=admin,DC=example,DC=com"
password = "secret"

# Create an LDAP connection object
conn = ldap.initialize(host, port)

# Bind to the LDAP directory
conn.bind_s(user, password)

# Search for the user with the given username
filter = "(uid=johndoe)"
results = conn.search(base="dc=example,dc=com", filter=filter)

# Print the user's DN
for entry in results:
    print(entry.dn)

# Close the LDAP connection
conn.close()
# Out:
#   Cell In[6], line 1
#     import python-ldap
#                  ^
# SyntaxError: invalid syntax

# %%
pip install ldap
# Out:
# ...
#   Using cached ldap-2.0.0.404.tar.gz (2.0 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   DEPRECATION: ldap is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for ldap ... error
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for ldap did not run successfully.
#   │ exit code: 1
#   ╰─> [100 lines of output]
#       running install
#       /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running build_py
# ...

# %%
pip install python-ldap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.4/377.4 kB 362.7 kB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.9/83.9 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 732.6 kB/s eta 0:00:00a 0:00:01
# ...
#   Created wheel for python-ldap: filename=python_ldap-3.4.3-cp311-cp311-macosx_10_9_universal2.whl size=307545 sha256=7b7600317cae16c6409d28d2facda9a97019d364929d80b98cbfe69437073beb
#   Stored in directory: /Users/macbook/Library/Caches/pip/wheels/68/aa/24/0aa68d59caf381a2b8995c1d69fecda71989be24dcac0ef827
# Successfully built python-ldap
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import ldap

# Define the LDAP connection parameters
host = "ldap://192.168.1.1"
port = 389
user = "CN=admin,DC=example,DC=com"
password = "secret"

# Create an LDAP connection object
conn = ldap.initialize(host, port)

# Bind to the LDAP directory
conn.bind_s(user, password)

# Search for the user with the given username
filter = "(uid=johndoe)"
results = conn.search(base="dc=example,dc=com", filter=filter)

# Print the user's DN
for entry in results:
    print(entry.dn)

# Close the LDAP connection
conn.close()
# Out:
# *** <ldap.ldapobject.SimpleLDAPObject object at 0x10564c150> ldap://192.168.1.1 - SimpleLDAPObject.set_option
# ((17, 3), {})
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/macbook/Library/Python/3.11/lib/python/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/macbook/Library/Python/3.11/lib/python/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#     app.start()
#   File "/Users/macbook/Library/Python/3.11/lib/python/site-packages/ipykernel/kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "/Users/macbook/Library/Python/3.11/lib/python/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
# ...
